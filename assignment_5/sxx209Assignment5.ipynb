# %% [markdown]
# # Intelligent Systems 2022: 5th  practical assignment
#
# ## Adversarial Games
#
#
# Your name: Sebastião Manuel Inácio Rosalino
#
# Your VUnetID: sxx209
#
# If you do not provide your name and VUnetID we will not accept your submission.
#
# ### Learning objectives
# At the end of this exercise you should be able to use the Schnapsen platform, run basic games between agents, and run tournaments in order to evaluate rational agents (also called bots). You should also be able to identify the working patterns of the MiniMiax algorithm in this platform and the improvements with Alpha/Beta pruning.
#
# 1. Follow the individual steps and explain the MiniMax algorithm
# 2. Make small modifications of the code to see the effect on the search algorithms
# 3. Make small adaptations to the algorithm to study the computational properties
#
# ### Practicalities
#
# Follow this Notebook step-by-step.
#
# Of course, you can do the exercises in any Programming Editor of your liking. But you do not have to. Feel free to simply write code in the Notebook. Please use your studentID+Assignment5.ipynb as the name of the Notebook.
#
# Note: unlike the courses dedicated to programming we will not evaluate the style of the programs. But we will, however, test your programs on other data that we provide, and your program should give the correct output to the test-data as well.
#
# As was mentioned, the assignment is graded as pass/fail. To pass you need to have either a full working code or an explanation of what you tried and what didn't work for the tasks that you were unable to complete (you can use multi-line comments or a text cell).
#
# ## Initialising
#
# First, let us make sure the necessary packages are installed, and imported. Run the following code:

# %%
import sys, random

from api import State, engine, util

# %% [markdown]
# ## MINIMAX Adversarial Games
# Now we will build some bots that search the game tree by using the MiniMax algorithm and show genuinely intelligent behavior. Because we only have partial information, and as there would be too many belief-states, we play these bots on the 2nd phase of the game only, when the stock has been exhausted, such that the state of all cards is known and no assumptions have to be made.

# %% [markdown]
# All you need to do to finish the minimax bot (see Task 1). The skeleton given in the code differs slightly from the pseudocode from the lecture in that instead of having two sub-methods, all is implemented in one method. Take your time to really understand the minimax algorithm, recursion, and the rest of the code.
# The following pseudo code can help you to finish Task 1.

# %% [raw]
# function VALUE(state) returns a utility value, move
#   # First we initialise the values for best_value (which we need to calculate the MIN and MAX later.
#   best_value = -infinity if MAXMOVE, +infinity if MINMOVE
#   # then we check for the terminal states of our search tree, either if there are no more successors, or in case we ran over the maximal depths (set in minimax.py)
#   if TERMINAL-TEST(state) then return UTILITY(state)
#   if DEPTH = max_depth then return heuristic_value(state)
#
#   # Now we calculate the values of the successor states, and choose the maximal one (or minimal) depending in which state we are.
#   for move in SUCCESSORS(state) do
#     next_move = SUCCESSOR(move)
#     value = VALUE(next_move)   # This is a recursive call, in which we calculate the optimal value for the opponent to play
#
#     if MAXMOVE # This is information provided by the game-engine as a function in the state class.
#         best_value is now calculated as the maximum between the value of the next_move and the previously calculated value (!)
#         best_move is set to the the move with the current best value  (!)
#     else
#         best_value is now calculated as the minimum between the value of the next_move and the previously calculated value  (!)
#         best_move is set to the the move with the current best value  (!)
#   return best_value, best_move

# %% [markdown]
# ### Task 1
# Implement the parts of the algorithm marked "???" in the code  (starting in line 65) of the minimax.py program in the bot directory. Please write down your new code in the following raw cell.
#
# Once you have done this, you can check whether you algorithm runs correctly.

# %%
MyCode1 ="""

if maximizing(state):  # we are in the Maximize part of the algorithm
                if value > best_value:
                    best_value = value
                    best_move = move
            else:      # we are in the Minimize part of the algorithm
                if value < best_value:
                    best_value = value
                    best_move = move

        return best_value, best_move

"""

# %%
# Choose your first player
player1 = "rand"
player2 = "minimax"
# Decide in which phase you want to start the game. 
startphase = 2
# Decide whether you want verbose output or not 
verbose=True

#And here you run a game on the engine. 
engine.play(util.load_player(player1),util.load_player(player2), state=State.generate(phase=startphase), max_time=10000, verbose=verbose)
# Out:
# player1: <bots.rand.rand.Bot object at 0x0000022BEA2FFA90>
# player2: <bots.minimax.minimax.Bot object at 0x0000022BEA2FC1F0>
# *   Player 1 plays: KC
# *   Player 1 melds a marriage between KC and QC
# The game is in phase: 2
# Player 1's points: 26, pending: 20
# Player 2's points: 26, pending: 0
# The trump suit is: S
# Player 1's hand: 10C KC QC AD 10S
# Player 2's hand: 10D QD AH KS JS
# There are 0 cards in the stock
# Player 1 has played card: K of C
#
# *   Player 2 plays: KS
# The game is in phase: 2
# Player 1's points: 26, pending: 20
# Player 2's points: 34, pending: 0
# The trump suit is: S
# Player 1's hand: 10C QC AD 10S
# Player 2's hand: 10D QD AH JS
# There are 0 cards in the stock
#
# *   Player 2 plays: JS
# The game is in phase: 2
# Player 1's points: 26, pending: 20
# Player 2's points: 34, pending: 0
# The trump suit is: S
# Player 1's hand: 10C QC AD 10S
# Player 2's hand: 10D QD AH JS
# There are 0 cards in the stock
# Player 2 has played card: J of S
#
# *   Player 1 plays: 10S
# The game is in phase: 2
# Player 1's points: 58, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: S
# Player 1's hand: 10C QC AD
# Player 2's hand: 10D QD AH
# There are 0 cards in the stock
#
# *   Player 1 plays: QC
# The game is in phase: 2
# Player 1's points: 58, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: S
# Player 1's hand: 10C QC AD
# Player 2's hand: 10D QD AH
# There are 0 cards in the stock
# Player 1 has played card: Q of C
#
# *   Player 2 plays: QD
# The game is in phase: 2
# Player 1's points: 64, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: S
# Player 1's hand: 10C AD
# Player 2's hand: 10D AH
# There are 0 cards in the stock
#
# *   Player 1 plays: 10C
# The game is in phase: 2
# Player 1's points: 64, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: S
# Player 1's hand: 10C AD
# Player 2's hand: 10D AH
# There are 0 cards in the stock
# Player 1 has played card: 10 of C
#
# *   Player 2 plays: AH
# The game is in phase: 2
# Player 1's points: 85, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: S
# Player 1's hand: AD
# Player 2's hand: 10D
# There are 0 cards in the stock
#
# Game finished. Player 1 has won, receiving 1 points.
# (1, 1)

# %% [markdown]
# ## Heuristics
#
# ### Task 2
#
# What heuristic do these implementations use? Explain the heuristic function in your own words:

# %%
Report1 = """

The bot Rand, represented by player 1 on the previous match up, sets its playstyle on the implementation that follows the simple heuristic of gathering 
all the legal moves and playing randomly among those moves.
However, the bot represented by player 2 on the previous match up, sets its playstyle on an implementation following the Minimax algorithm.
Moreover, its heuristic will assign an heuristic value to every state, ranging from -1 to 1, meaning that -1 is an absolute certain victory for player
2 and 1 stands for an absolute certain victory for player 1. Notheworthy to mention that, every value between that interval represents an estimation for 
the chances of victory of both players (assessing the "goodness" of every state to both players 1 and 2). Having made this heuristical assignment to 
every possible state, the players will then pick the states that appear to be the most promising in order to achieve victory based on the move quality
estimation calculated by the heuristic function present on Minimax's implementation.  

"""

# %% [markdown]
# Adapt the search depth (in the constructor of the Minimax bot, and adapt the Minimax procedure by uncommenting the respective function) to smaller values (search depths). Report on the performance of these different versions of using the heuristics against some other players (like rdeep and rand), and see if the performance (nr. of games won) differs with the different look-aheads.
#
# ### Task 3
# Report on your experiments with Minimax as compared to previous bots (or a copy of MiniMax with a different search depths)

# %%
# Choose your first player
player1 = "rand"
player2 = "minimax"
# Decide in which phase you want to start the game. 
startphase = 2
# Decide whether you want verbose output or not 
verbose=True

#And here you run a game on the engine. 
engine.play(util.load_player(player1),util.load_player(player2), state=State.generate(phase=startphase), max_time=10000, verbose=verbose)
# Out:
# player1: <bots.rand.rand.Bot object at 0x0000022BEA2FD600>
# player2: <bots.minimax.minimax.Bot object at 0x0000022BEA2FFE20>
# *   Player 1 plays: QC
# The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: D
# Player 1's hand: AC QC KH QH KS
# Player 2's hand: JC KD JD AH 10H
# There are 0 cards in the stock
# Player 1 has played card: Q of C
#
# *   Player 2 plays: JC
# The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: D
# Player 1's hand: AC KH QH KS
# Player 2's hand: KD JD AH 10H
# There are 0 cards in the stock
#
# *   Player 1 plays: AC
# The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: D
# Player 1's hand: AC KH QH KS
# Player 2's hand: KD JD AH 10H
# There are 0 cards in the stock
# Player 1 has played card: A of C
#
# *   Player 2 plays: JD
# The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 46, pending: 0
# The trump suit is: D
# Player 1's hand: KH QH KS
# Player 2's hand: KD AH 10H
# There are 0 cards in the stock
#
# *   Player 2 plays: 10H
# The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 46, pending: 0
# The trump suit is: D
# Player 1's hand: KH QH KS
# Player 2's hand: KD AH 10H
# There are 0 cards in the stock
# Player 2 has played card: 10 of H
#
# *   Player 1 plays: QH
# The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 59, pending: 0
# The trump suit is: D
# Player 1's hand: KH KS
# Player 2's hand: KD AH
# There are 0 cards in the stock
#
# *   Player 2 plays: KD
# The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 59, pending: 0
# The trump suit is: D
# Player 1's hand: KH KS
# Player 2's hand: KD AH
# There are 0 cards in the stock
# Player 2 has played card: K of D
#
# *   Player 1 plays: KH
# The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 67, pending: 0
# The trump suit is: D
# Player 1's hand: KS
# Player 2's hand: AH
# There are 0 cards in the stock
#
# Game finished. Player 2 has won, receiving 1 points.
# (2, 1)

# %%
# Choose your first player
player1 = "rdeep"
player2 = "minimax"
# Decide in which phase you want to start the game. 
startphase = 2
# Decide whether you want verbose output or not 
verbose=True

#And here you run a game on the engine. 
engine.play(util.load_player(player1),util.load_player(player2), state=State.generate(phase=startphase), max_time=10000, verbose=verbose)
# Out:
# player1: <bots.rdeep.rdeep.Bot object at 0x0000022BEA2FF490>
# player2: <bots.minimax.minimax.Bot object at 0x0000022BEA2FF670>
# *   Player 1 plays: AH
# The game is in phase: 2
# Player 1's points: 37, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: S
# Player 1's hand: QC JC KD AH QH
# Player 2's hand: AC KC JH QS JS
# There are 0 cards in the stock
# Player 1 has played card: A of H
#
# *   Player 2 plays: JH
# The game is in phase: 2
# Player 1's points: 50, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: S
# Player 1's hand: QC JC KD QH
# Player 2's hand: AC KC QS JS
# There are 0 cards in the stock
#
# *   Player 1 plays: QH
# The game is in phase: 2
# Player 1's points: 50, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: S
# Player 1's hand: QC JC KD QH
# Player 2's hand: AC KC QS JS
# There are 0 cards in the stock
# Player 1 has played card: Q of H
#
# *   Player 2 plays: QS
# The game is in phase: 2
# Player 1's points: 50, pending: 0
# Player 2's points: 43, pending: 0
# The trump suit is: S
# Player 1's hand: QC JC KD
# Player 2's hand: AC KC JS
# There are 0 cards in the stock
#
# *   Player 2 plays: AC
# The game is in phase: 2
# Player 1's points: 50, pending: 0
# Player 2's points: 43, pending: 0
# The trump suit is: S
# Player 1's hand: QC JC KD
# Player 2's hand: AC KC JS
# There are 0 cards in the stock
# Player 2 has played card: A of C
#
# *   Player 1 plays: JC
# The game is in phase: 2
# Player 1's points: 50, pending: 0
# Player 2's points: 56, pending: 0
# The trump suit is: S
# Player 1's hand: QC KD
# Player 2's hand: KC JS
# There are 0 cards in the stock
#
# *   Player 2 plays: JS
# The game is in phase: 2
# Player 1's points: 50, pending: 0
# Player 2's points: 56, pending: 0
# The trump suit is: S
# Player 1's hand: QC KD
# Player 2's hand: KC JS
# There are 0 cards in the stock
# Player 2 has played card: J of S
#
# *   Player 1 plays: QC
# The game is in phase: 2
# Player 1's points: 50, pending: 0
# Player 2's points: 61, pending: 0
# The trump suit is: S
# Player 1's hand: KD
# Player 2's hand: KC
# There are 0 cards in the stock
#
# *   Player 2 plays: KC
# The game is in phase: 2
# Player 1's points: 50, pending: 0
# Player 2's points: 61, pending: 0
# The trump suit is: S
# Player 1's hand: KD
# Player 2's hand: KC
# There are 0 cards in the stock
# Player 2 has played card: K of C
#
# *   Player 1 plays: KD
# The game is in phase: 2
# Player 1's points: 50, pending: 0
# Player 2's points: 69, pending: 0
# The trump suit is: S
# Player 1's hand:
# Player 2's hand:
# There are 0 cards in the stock
#
# Game finished. Player 2 has won, receiving 1 points.
# (2, 1)

# %%
Report2 = """

By decreasing the search depth performed by the Minimax bot to a value of 2, I was able to conclude that even with this lower amount of look-aheads,
this bot was able to beat Rand. The same is no longer true for the match up between Rdeep and Minimax. In this game, the amount of 2 look-aheads proved 
to be too low and Rdeep ended up winning. I then decided to increase the amount of look-aheads on the Minimax bot to the number of total cards that both 
players will have in their hands on phase 2 of the Schnapsen game, (5 cards for each player meaning 10 cards in total), and the results were quite 
different. The Minimax bot defeated Rand and Rdeep. This outcome is largely due to the strategic superiority of Minimax, since, when performing in a 
situation of perfect information (phase 2), this bot is able to effectively find a path to victory if such scenario is possible, whereas the other two 
bots base their playstyles on probabilities (Rand as mentioned in previous tasks plays in a completely random way and Rdeep as mentioned in previous 
assignments bases its playstyle on the PIMS paradigm).
Finally, in order to empirically confirm the emerging hypothesis that the minimum number of look-aheads for Minimax to operate with its full prediction 
capacity (intuitively 10 since it is the total number of cards still yet to be played as soon as phase 2 of the game starts), I decided to increase 
Minimax's search depth to 20 and the results were the same as with the 10 search depth level, as Minimax secured victories over Rand and Ddeep.

"""

# %% [markdown]
# ## Alphabeta
#
# Finally let us look at Alphabeta pruning. Alphabeta pruning is a technique to make minimax faster. If implemented correctly, it will do exactly the same  thing minimax does, but skip large parts of the search tree. We've provided a basic implementation in bots/alphabeta/alphabeta.py.
#
# ### Task 4
#
# Once again, one crucial bit of the implementation are missing, the decision on when to prune. Finish the implementation of the alphabeta bot. Copy the line of code you adapted in the skeleton file alphabeta.py into the following cell:

# %%
MyCode2 ="""

if alpha >= beta:
    break

"""

# %% [markdown]
# The following programme lets you see if you implemented alphabeta and minimax correctly. Run it, and check the outcome.

# %%
from api import State, util
import random, time

from bots.alphabeta import alphabeta
from bots.minimax import minimax

REPEATS = 100      
DEPTH = 6

ab = alphabeta.Bot(randomize=False, depth=DEPTH)
mm = minimax.Bot(randomize=False, depth=DEPTH)

mm_time = 0
ab_time = 0

# Repeat
for r in range(REPEATS):
    
    # Repeat some more 
    for r2 in range(REPEATS):

        # Generate a starting state
        state = State.generate(phase=2)

        # Ask both bots their move
        # (and time their responses)

        start = time.time()
        mm_move = mm.get_move(state)
        mm_time += (time.time() - start)

        start = time.time()
        ab_move = ab.get_move(state)
        ab_time += (time.time() - start)

        if mm_move != ab_move:
            print('Difference of opinion! Minimax said: {}, alphabeta said: {}. State: {}'.format(mm_move, ab_move, state))
        else:
            print('Agreed.')

print('Done. time Minimax: {}, time Alphabeta: {}.'.format(mm_time/REPEATS, ab_time/REPEATS))
print('Alphabeta speedup: {} '.format(mm_time/ab_time))
# Out:
# Agreed.
# Difference of opinion! Minimax said: (7, None), alphabeta said: (5, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: S
# Player 1's hand: AD KD 10H QH KS
# Player 2's hand: 10C JC AH 10S QS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (5, None). State: The game is in phase: 2
# Player 1's points: 22, pending: 0
# Player 2's points: 22, pending: 0
# The trump suit is: S
# Player 1's hand: 10C QC AD AH KS
# Player 2's hand: AC 10H QH AS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (15, None), alphabeta said: (6, None). State: The game is in phase: 2
# Player 1's points: 36, pending: 0
# Player 2's points: 36, pending: 0
# The trump suit is: C
# Player 1's hand: 10D JD AH KH AS
# Player 2's hand: AC JC AD QD QS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (11, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 27, pending: 0
# Player 2's points: 27, pending: 0
# The trump suit is: D
# Player 1's hand: AC JD 10H KH AS
# Player 2's hand: AD 10D QH JH JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (7, 8), alphabeta said: (19, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: D
# Player 1's hand: QC AD 10D QH JH
# Player 2's hand: 10C KD QD KH JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (18, None), alphabeta said: (13, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: C
# Player 1's hand: QH JH AS QS JS
# Player 2's hand: JC AD AH 10H KH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (13, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 52, pending: 0
# Player 2's points: 52, pending: 0
# The trump suit is: H
# Player 1's hand: AC KC QC JH QS
# Player 2's hand: 10C AD KD QH KS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 35, pending: 0
# Player 2's points: 35, pending: 0
# The trump suit is: H
# Player 1's hand: QD JD JH 10S JS
# Player 2's hand: 10C JC 10D KD KH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (6, None), alphabeta said: (16, None). State: The game is in phase: 2
# Player 1's points: 32, pending: 0
# Player 2's points: 32, pending: 0
# The trump suit is: C
# Player 1's hand: KC KD QD KH KS
# Player 2's hand: 10D AH QH 10S JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (11, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 38, pending: 0
# The trump suit is: H
# Player 1's hand: QC 10H QH AS JS
# Player 2's hand: KD QD JD KH JH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (3, None), alphabeta said: (13, None). State: The game is in phase: 2
# Player 1's points: 36, pending: 0
# Player 2's points: 36, pending: 0
# The trump suit is: D
# Player 1's hand: QC JD 10H QH KS
# Player 2's hand: AC 10C QD AS 10S
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (15, None), alphabeta said: (10, None). State: The game is in phase: 2
# Player 1's points: 37, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: D
# Player 1's hand: JD AH JH AS KS
# Player 2's hand: KC QC KD QD JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (15, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 23, pending: 0
# Player 2's points: 23, pending: 0
# The trump suit is: H
# Player 1's hand: AD 10H JH 10S JS
# Player 2's hand: 10C KC QC 10D AS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (4, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 31, pending: 0
# Player 2's points: 31, pending: 0
# The trump suit is: H
# Player 1's hand: AD KD JD 10H JH
# Player 2's hand: AC JC 10S KS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (1, None), alphabeta said: (15, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: H
# Player 1's hand: AD JD 10H JH 10S
# Player 2's hand: 10C QC AH AS KS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (4, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: D
# Player 1's hand: QD KH AS QS JS
# Player 2's hand: KC QC JC AD AH
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (16, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 32, pending: 0
# Player 2's points: 32, pending: 0
# The trump suit is: S
# Player 1's hand: AD JD 10H JH JS
# Player 2's hand: 10C JC QD KH 10S
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: S
# Player 1's hand: KC JC 10D 10H 10S
# Player 2's hand: KD QD KH KS QS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (6, None). State: The game is in phase: 2
# Player 1's points: 22, pending: 0
# Player 2's points: 22, pending: 0
# The trump suit is: C
# Player 1's hand: 10D JD AH AS QS
# Player 2's hand: 10C AD QD KH 10S
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (0, None), alphabeta said: (11, None). State: The game is in phase: 2
# Player 1's points: 35, pending: 0
# Player 2's points: 35, pending: 0
# The trump suit is: S
# Player 1's hand: JC KD JD KS QS
# Player 2's hand: AC 10D 10H JH JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (9, None), alphabeta said: (6, None). State: The game is in phase: 2
# Player 1's points: 51, pending: 0
# Player 2's points: 51, pending: 0
# The trump suit is: S
# Player 1's hand: AC JC JH 10S JS
# Player 2's hand: 10D JD KH AS QS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: AC JC 10D AH QS
# Player 2's hand: KD QD JD AS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 28, pending: 0
# Player 2's points: 28, pending: 0
# The trump suit is: D
# Player 1's hand: 10C QC AD 10D JH
# Player 2's hand: AC JD 10H QS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (11, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 31, pending: 0
# Player 2's points: 31, pending: 0
# The trump suit is: C
# Player 1's hand: JC KD 10H AS JS
# Player 2's hand: QC AD JD JH 10S
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (7, None). State: The game is in phase: 2
# Player 1's points: 36, pending: 0
# Player 2's points: 36, pending: 0
# The trump suit is: C
# Player 1's hand: 10D KD KH 10S JS
# Player 2's hand: AC AD QD 10H QH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (6, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 27, pending: 0
# Player 2's points: 27, pending: 0
# The trump suit is: S
# Player 1's hand: 10C KC QC 10D 10S
# Player 2's hand: JD AH JH AS QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (16, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: D
# Player 1's hand: AC 10C JD KS JS
# Player 2's hand: KC KH JH 10S QS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (14, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: S
# Player 1's hand: 10C JC KD QD JH
# Player 2's hand: AC AD KH AS 10S
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (7, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 37, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: S
# Player 1's hand: QD JD AS KS QS
# Player 2's hand: QC KD QH JH 10S
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 25, pending: 0
# Player 2's points: 25, pending: 0
# The trump suit is: D
# Player 1's hand: KC AD KH AS JS
# Player 2's hand: 10D KD 10H QH 10S
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (8, None), alphabeta said: (6, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: S
# Player 1's hand: KC JH 10S KS QS
# Player 2's hand: 10D QD AH KH AS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (2, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: S
# Player 1's hand: AC KC JC AH 10S
# Player 2's hand: AD KD JD KS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (18, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: C
# Player 1's hand: AH QH JH QS JS
# Player 2's hand: 10C JC KH AS KS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: C
# Player 1's hand: QC QD AH KS JS
# Player 2's hand: KC 10D KH JH AS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (10, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 37, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: S
# Player 1's hand: QD KH JH AS JS
# Player 2's hand: KC JC JD AH KS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (15, None), alphabeta said: (8, None). State: The game is in phase: 2
# Player 1's points: 27, pending: 0
# Player 2's points: 27, pending: 0
# The trump suit is: S
# Player 1's hand: QC 10D KD AH JS
# Player 2's hand: QD 10H JH AS 10S
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (7, None). State: The game is in phase: 2
# Player 1's points: 32, pending: 0
# Player 2's points: 32, pending: 0
# The trump suit is: C
# Player 1's hand: KD JD AH 10H KH
# Player 2's hand: AC KC QH KS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (18, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: C
# Player 1's hand: AH 10H QH QS JS
# Player 2's hand: JC QD KH AS KS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (4, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 35, pending: 0
# Player 2's points: 35, pending: 0
# The trump suit is: D
# Player 1's hand: AC 10C JC QH JS
# Player 2's hand: QD JD KH 10S QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (0, None), alphabeta said: (17, 18). State: The game is in phase: 2
# Player 1's points: 25, pending: 0
# Player 2's points: 25, pending: 0
# The trump suit is: H
# Player 1's hand: QC JC AD 10H KH
# Player 2's hand: AC 10D AH KS QS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (1, None), alphabeta said: (8, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: 10C QD JD 10H KS
# Player 2's hand: QC AH QH AS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (15, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: S
# Player 1's hand: 10C JC KD 10H KS
# Player 2's hand: AD 10D KH AS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (0, None), alphabeta said: (16, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: C
# Player 1's hand: AC 10D KH 10S QS
# Player 2's hand: QC JC AD JD AH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (17, 18), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: D
# Player 1's hand: 10C QD AH QH JS
# Player 2's hand: KC 10H KH KS QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (0, None), alphabeta said: (5, None). State: The game is in phase: 2
# Player 1's points: 39, pending: 0
# Player 2's points: 39, pending: 0
# The trump suit is: S
# Player 1's hand: KC QD AH KH JS
# Player 2's hand: AC QC AD JD 10H
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (4, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 38, pending: 0
# The trump suit is: D
# Player 1's hand: KD QD JD QS JS
# Player 2's hand: KC JC 10D JH AS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (10, None), alphabeta said: (7, 8). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: D
# Player 1's hand: AC 10C JD QH 10S
# Player 2's hand: QC KD QD AH JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (3, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: S
# Player 1's hand: 10D QD QH AS JS
# Player 2's hand: AC QC JC KD JD
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: D
# Player 1's hand: 10C KC JD 10H QH
# Player 2's hand: QC AH KH JH JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 43, pending: 0
# Player 2's points: 43, pending: 0
# The trump suit is: H
# Player 1's hand: AC KC AD KD JD
# Player 2's hand: 10D QD QH KS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (1, None), alphabeta said: (16, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: KC QC JC AD QS
# Player 2's hand: 10C 10D QD 10S KS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: H
# Player 1's hand: KC KD AH KH JH
# Player 2's hand: QC 10D JD 10H KS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 46, pending: 0
# Player 2's points: 46, pending: 0
# The trump suit is: D
# Player 1's hand: JD AH 10H KH 10S
# Player 2's hand: 10C KC AD KD JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (9, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: H
# Player 1's hand: 10C QC JC JD KH
# Player 2's hand: AC KC 10D QH JH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (15, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 31, pending: 0
# Player 2's points: 31, pending: 0
# The trump suit is: H
# Player 1's hand: 10C JC QD AS KS
# Player 2's hand: 10D JD AH QS JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: C
# Player 1's hand: AC KC QC QD JS
# Player 2's hand: 10C JC 10D KD JD
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (0, None), alphabeta said: (6, None). State: The game is in phase: 2
# Player 1's points: 39, pending: 0
# Player 2's points: 39, pending: 0
# The trump suit is: D
# Player 1's hand: KC KD QD 10H 10S
# Player 2's hand: AC QC 10D QH KS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: D
# Player 1's hand: 10C 10D 10H KS JS
# Player 2's hand: KD QD QH JH AS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (12, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 23, pending: 0
# Player 2's points: 23, pending: 0
# The trump suit is: C
# Player 1's hand: AC 10C 10H JH AS
# Player 2's hand: QC JC AD 10D KH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (15, None), alphabeta said: (13, None). State: The game is in phase: 2
# Player 1's points: 27, pending: 0
# Player 2's points: 27, pending: 0
# The trump suit is: S
# Player 1's hand: 10C QC AH 10H JS
# Player 2's hand: QH JH AS 10S QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 38, pending: 0
# The trump suit is: C
# Player 1's hand: JC AD 10D KH JS
# Player 2's hand: KC QC KD JD JH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 21, pending: 0
# Player 2's points: 21, pending: 0
# The trump suit is: D
# Player 1's hand: AC KD AS 10S KS
# Player 2's hand: 10C QC AD 10D KH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (10, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: H
# Player 1's hand: AD JD QH JH AS
# Player 2's hand: AC AH KH 10S JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (7, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 37, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: C
# Player 1's hand: QC KD AS KS JS
# Player 2's hand: AC KC JC JD QH
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (2, None), alphabeta said: (17, 18). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: H
# Player 1's hand: KC JC 10H KS QS
# Player 2's hand: 10C 10D AH KH 10S
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (11, None), alphabeta said: (15, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: D
# Player 1's hand: 10H KH AS 10S QS
# Player 2's hand: 10C KC QD QH JH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (15, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 35, pending: 0
# Player 2's points: 35, pending: 0
# The trump suit is: C
# Player 1's hand: 10C QC AD AH KS
# Player 2's hand: KC 10D KD AS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (10, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: S
# Player 1's hand: AC QD AH JH QS
# Player 2's hand: 10D 10H KH QH 10S
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (10, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 31, pending: 0
# Player 2's points: 31, pending: 0
# The trump suit is: D
# Player 1's hand: 10D JD 10H JH QS
# Player 2's hand: QC JC KD AH 10S
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 27, pending: 0
# Player 2's points: 27, pending: 0
# The trump suit is: C
# Player 1's hand: 10C JD AH 10H 10S
# Player 2's hand: AC QC JC KH JH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (2, None), alphabeta said: (5, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: 10C KC AD KD 10S
# Player 2's hand: AC QC JH QS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (18, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 22, pending: 0
# Player 2's points: 22, pending: 0
# The trump suit is: D
# Player 1's hand: 10C QC JD 10S QS
# Player 2's hand: AC KC AD 10D AH
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 35, pending: 0
# Player 2's points: 35, pending: 0
# The trump suit is: S
# Player 1's hand: 10C 10D QD QH QS
# Player 2's hand: QC JC AD JH JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (15, None), alphabeta said: (13, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: D
# Player 1's hand: 10D QH AS 10S KS
# Player 2's hand: 10C JC AD KD JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (3, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 36, pending: 0
# Player 2's points: 36, pending: 0
# The trump suit is: H
# Player 1's hand: 10C KC QC KD QS
# Player 2's hand: AD QD QH JH KS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (16, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 38, pending: 0
# The trump suit is: H
# Player 1's hand: QC JD QH 10S KS
# Player 2's hand: 10C JC KH QS JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (2, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: S
# Player 1's hand: KC JC AD 10D JH
# Player 2's hand: AC QC KH AS QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: 10C QC AD JD KS
# Player 2's hand: QD QH AS 10S QS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (7, None). State: The game is in phase: 2
# Player 1's points: 36, pending: 0
# Player 2's points: 36, pending: 0
# The trump suit is: S
# Player 1's hand: 10D QD KH 10S JS
# Player 2's hand: KD JD AH 10H AS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (14, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: S
# Player 1's hand: KH QH AS 10S KS
# Player 2's hand: AC KC JC JH QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (12, 13), alphabeta said: (7, None). State: The game is in phase: 2
# Player 1's points: 37, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: H
# Player 1's hand: KD KH QH KS JS
# Player 2's hand: QC AD 10D QD JH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (7, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: 10C JC KD AS JS
# Player 2's hand: 10D KH QH 10S KS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (2, None), alphabeta said: (16, None). State: The game is in phase: 2
# Player 1's points: 39, pending: 0
# Player 2's points: 39, pending: 0
# The trump suit is: S
# Player 1's hand: JC QD AH KS QS
# Player 2's hand: KC AD KD 10H 10S
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (12, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: H
# Player 1's hand: AC 10D QH JH QS
# Player 2's hand: KC JC JD KH AS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (15, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: C
# Player 1's hand: AC QC KD QH QS
# Player 2's hand: 10D 10H JH AS 10S
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (0, None), alphabeta said: (6, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: AC KC 10D QH QS
# Player 2's hand: QC AH JH AS JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (7, None). State: The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 38, pending: 0
# The trump suit is: H
# Player 1's hand: QC JC 10D QH KS
# Player 2's hand: KD QD JD AH JH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 35, pending: 0
# Player 2's points: 35, pending: 0
# The trump suit is: S
# Player 1's hand: JC AH 10H KH JH
# Player 2's hand: AC JD QH QS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (17, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 35, pending: 0
# Player 2's points: 35, pending: 0
# The trump suit is: S
# Player 1's hand: QC JC 10S KS JS
# Player 2's hand: 10D JD QH AS QS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (8, None), alphabeta said: (5, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: H
# Player 1's hand: AD 10D QD JD QS
# Player 2's hand: 10C QC AH JH KS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: H
# Player 1's hand: QC AD AH QH KS
# Player 2's hand: 10C KD JD JH QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 37, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: S
# Player 1's hand: AC JC QD QS JS
# Player 2's hand: KC AD QH JH KS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (7, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 32, pending: 0
# Player 2's points: 32, pending: 0
# The trump suit is: C
# Player 1's hand: AC QC QD 10S QS
# Player 2's hand: 10C KC KD QH KS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: 10C 10D QD JH KS
# Player 2's hand: JD AH KH AS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (16, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: S
# Player 1's hand: AC AH JH QS JS
# Player 2's hand: KC JC QD QH 10S
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: C
# Player 1's hand: JC AD JD 10H QH
# Player 2's hand: AC QC KD JH AS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (0, None), alphabeta said: (11, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: H
# Player 1's hand: QC JC 10D QH JH
# Player 2's hand: AC 10C KC 10H KS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (12, 13), alphabeta said: (6, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: S
# Player 1's hand: 10D KH QH KS QS
# Player 2's hand: AC 10C QC JC AS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: H
# Player 1's hand: 10C QC KD 10H QS
# Player 2's hand: KC AD QD JD KS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (8, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 37, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: H
# Player 1's hand: KD QH JH KS JS
# Player 2's hand: AC QD KH 10S QS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (15, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: KC JC AH JH JS
# Player 2's hand: QC 10H AS 10S KS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (16, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: D
# Player 1's hand: 10C KC QH 10S QS
# Player 2's hand: AC QC JC 10D KS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (9, None). State: The game is in phase: 2
# Player 1's points: 37, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: C
# Player 1's hand: 10D JD JH KS JS
# Player 2's hand: KC QC AD KD QD
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (17, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: H
# Player 1's hand: AC 10C 10H JH QS
# Player 2's hand: JC KD QD KS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (11, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 38, pending: 0
# The trump suit is: S
# Player 1's hand: 10C KD JD JH KS
# Player 2's hand: KC QC JC QD 10H
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (0, None), alphabeta said: (10, None). State: The game is in phase: 2
# Player 1's points: 27, pending: 0
# Player 2's points: 27, pending: 0
# The trump suit is: H
# Player 1's hand: QC JC 10H JH QS
# Player 2's hand: AC 10C KC AH 10S
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (17, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 39, pending: 0
# Player 2's points: 39, pending: 0
# The trump suit is: H
# Player 1's hand: 10D AH 10H KH QS
# Player 2's hand: 10C KC QH JH KS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (10, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 32, pending: 0
# Player 2's points: 32, pending: 0
# The trump suit is: H
# Player 1's hand: JC KD QD AH KH
# Player 2's hand: AC AD QH KS JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (16, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: KD AH 10H QH KS
# Player 2's hand: 10D KH JH 10S JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (2, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 31, pending: 0
# Player 2's points: 31, pending: 0
# The trump suit is: C
# Player 1's hand: AC JC JD 10S QS
# Player 2's hand: 10C KC QD 10H QH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: D
# Player 1's hand: KC JC AD 10H KS
# Player 2's hand: AC 10C JD AS QS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 31, pending: 0
# Player 2's points: 31, pending: 0
# The trump suit is: D
# Player 1's hand: AC QD JD 10S QS
# Player 2's hand: 10C 10D KD QH JH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (15, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: D
# Player 1's hand: AC AD JD QH 10S
# Player 2's hand: AH 10H JH AS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (19, None), alphabeta said: (16, None). State: The game is in phase: 2
# Player 1's points: 18, pending: 0
# Player 2's points: 18, pending: 0
# The trump suit is: D
# Player 1's hand: 10C 10D 10S KS JS
# Player 2's hand: AC AD AH 10H KH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: S
# Player 1's hand: AC QC AD 10D JH
# Player 2's hand: QD KH AS KS QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (1, None), alphabeta said: (5, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: S
# Player 1's hand: KC 10D QH JH QS
# Player 2's hand: 10C QC AD KD QD
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 31, pending: 0
# Player 2's points: 31, pending: 0
# The trump suit is: H
# Player 1's hand: AC 10D KH QH KS
# Player 2's hand: 10C AD AH 10H QS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (12, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: S
# Player 1's hand: AC KD QH 10S QS
# Player 2's hand: QC KH JH AS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (15, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: D
# Player 1's hand: 10C AD JD 10S QS
# Player 2's hand: KC KD AS KS JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: C
# Player 1's hand: 10C QD JD KS QS
# Player 2's hand: KC 10D KD KH 10S
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (0, None), alphabeta said: (16, None). State: The game is in phase: 2
# Player 1's points: 27, pending: 0
# Player 2's points: 27, pending: 0
# The trump suit is: H
# Player 1's hand: AC JC QD KH 10S
# Player 2's hand: 10C 10D KD 10H JH
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (8, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: KC QC QD 10H JH
# Player 2's hand: AC 10C JD AH QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (6, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 31, pending: 0
# Player 2's points: 31, pending: 0
# The trump suit is: D
# Player 1's hand: 10C KC JD QH JH
# Player 2's hand: QC 10D QD AH 10S
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (10, None), alphabeta said: (7, None). State: The game is in phase: 2
# Player 1's points: 27, pending: 0
# Player 2's points: 27, pending: 0
# The trump suit is: H
# Player 1's hand: 10C 10D JH 10S QS
# Player 2's hand: KD AH 10H QH JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 38, pending: 0
# The trump suit is: D
# Player 1's hand: JC QD JD KH 10S
# Player 2's hand: KC QC AH QH JH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (1, None), alphabeta said: (6, None). State: The game is in phase: 2
# Player 1's points: 22, pending: 0
# Player 2's points: 22, pending: 0
# The trump suit is: H
# Player 1's hand: 10C 10D 10H KS QS
# Player 2's hand: AC AH KH JH AS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 27, pending: 0
# Player 2's points: 27, pending: 0
# The trump suit is: D
# Player 1's hand: QD AH QH 10S QS
# Player 2's hand: 10C KC 10D 10H JH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (15, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 40, pending: 0
# Player 2's points: 40, pending: 0
# The trump suit is: S
# Player 1's hand: 10D JD 10H KH JS
# Player 2's hand: AC QC JH AS KS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (0, None), alphabeta said: (7, None). State: The game is in phase: 2
# Player 1's points: 37, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: S
# Player 1's hand: KC JC AD JD QS
# Player 2's hand: AC KD QD JH KS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (0, None), alphabeta said: (10, None). State: The game is in phase: 2
# Player 1's points: 27, pending: 0
# Player 2's points: 27, pending: 0
# The trump suit is: H
# Player 1's hand: 10C QC JH 10S KS
# Player 2's hand: AC 10D JD AH QS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: 10C KD QH JH QS
# Player 2's hand: QC JC AH 10H AS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (6, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: H
# Player 1's hand: QC JC 10D 10S QS
# Player 2's hand: JD AH KH JH KS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (15, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: H
# Player 1's hand: KC AH QH JH KS
# Player 2's hand: JC KD AS 10S JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (13, None), alphabeta said: (10, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: C
# Player 1's hand: 10C KC JC KD 10S
# Player 2's hand: AH QH JH QS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (15, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: S
# Player 1's hand: KC JC JD QH AS
# Player 2's hand: AD KD AH KS JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (19, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 31, pending: 0
# Player 2's points: 31, pending: 0
# The trump suit is: H
# Player 1's hand: 10C KC JC JH JS
# Player 2's hand: AD AH 10H QH QS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (11, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: QC 10H KH KS QS
# Player 2's hand: AD 10D QD JH 10S
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (6, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: C
# Player 1's hand: AC JC KD AH KS
# Player 2's hand: KC 10D 10H KH AS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (15, None), alphabeta said: (7, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: C
# Player 1's hand: KC JC AD 10S JS
# Player 2's hand: KD AH QH AS KS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (19, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 35, pending: 0
# Player 2's points: 35, pending: 0
# The trump suit is: H
# Player 1's hand: 10D JD 10H QH 10S
# Player 2's hand: QC KH JH KS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: D
# Player 1's hand: KC QC AD 10D KS
# Player 2's hand: AC QD JD 10H KH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (7, None), alphabeta said: (16, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: H
# Player 1's hand: AC 10C JC JD KH
# Player 2's hand: KC KD 10H 10S JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (13, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: C
# Player 1's hand: QC AD 10D QH QS
# Player 2's hand: 10C KD JD KH 10S
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (0, None), alphabeta said: (11, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: S
# Player 1's hand: QC 10D JD QH 10S
# Player 2's hand: AC AD KD 10H KS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (15, None), alphabeta said: (12, None). State: The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 38, pending: 0
# The trump suit is: C
# Player 1's hand: QC KH QH JH AS
# Player 2's hand: KC JC 10D JD JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (4, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 25, pending: 0
# Player 2's points: 25, pending: 0
# The trump suit is: C
# Player 1's hand: KC JC AS 10S QS
# Player 2's hand: AC AD 10D KD QH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (6, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 31, pending: 0
# Player 2's points: 31, pending: 0
# The trump suit is: S
# Player 1's hand: QD JD AS QS JS
# Player 2's hand: 10C QC 10D KD 10S
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (16, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 36, pending: 0
# Player 2's points: 36, pending: 0
# The trump suit is: D
# Player 1's hand: AD KD KH KS QS
# Player 2's hand: KC JC QH 10S JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (4, None), alphabeta said: (17, 18). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: H
# Player 1's hand: JC 10H 10S KS QS
# Player 2's hand: QC QD AH KH JH
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (3, None), alphabeta said: (18, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: H
# Player 1's hand: JC AD 10D QH AS
# Player 2's hand: QC QD 10H KH QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (9, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 27, pending: 0
# Player 2's points: 27, pending: 0
# The trump suit is: C
# Player 1's hand: 10C QC QD AH 10H
# Player 2's hand: JC JD AS 10S QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: H
# Player 1's hand: QC AD JH AS QS
# Player 2's hand: AC JC KD 10H JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (13, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 37, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: D
# Player 1's hand: AC 10C QH 10S QS
# Player 2's hand: AD 10D QD JH JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (15, None). State: The game is in phase: 2
# Player 1's points: 25, pending: 0
# Player 2's points: 25, pending: 0
# The trump suit is: C
# Player 1's hand: AC KD QD JD KH
# Player 2's hand: AD 10D AS 10S QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 22, pending: 0
# Player 2's points: 22, pending: 0
# The trump suit is: D
# Player 1's hand: AC 10D 10H KH QS
# Player 2's hand: QC JC AD AH AS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (11, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: H
# Player 1's hand: AD 10D QD KH JS
# Player 2's hand: QC JD 10H 10S KS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (10, None). State: The game is in phase: 2
# Player 1's points: 22, pending: 0
# Player 2's points: 22, pending: 0
# The trump suit is: H
# Player 1's hand: QD JH AS 10S QS
# Player 2's hand: AC 10C AD AH QH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# ...
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (4, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: AC AD QD AS KS
# Player 2's hand: QC JC JH 10S QS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (15, None), alphabeta said: (12, 13). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: JC QD KH QH AS
# Player 2's hand: AC 10C 10D KS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (10, None), alphabeta said: (7, None). State: The game is in phase: 2
# Player 1's points: 35, pending: 0
# Player 2's points: 35, pending: 0
# The trump suit is: C
# Player 1's hand: KD AH 10H 10S QS
# Player 2's hand: 10C KC KH AS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (4, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: H
# Player 1's hand: QC JC AD QH AS
# Player 2's hand: 10D JD 10H KS QS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (1, None), alphabeta said: (17, None). State: The game is in phase: 2
# Player 1's points: 50, pending: 0
# Player 2's points: 50, pending: 0
# The trump suit is: C
# Player 1's hand: 10C JD 10H KS JS
# Player 2's hand: KC JC 10D AH KH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: KC AH QH 10S JS
# Player 2's hand: 10C JD JH AS KS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: D
# Player 1's hand: 10C QC 10D KD QS
# Player 2's hand: KC AD 10H JH KS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (9, None), alphabeta said: (8, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: AC QD JD QH 10S
# Player 2's hand: AD AH JH KS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (11, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: H
# Player 1's hand: 10C JC 10H AS KS
# Player 2's hand: AC QC QD QH QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (3, 2), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: S
# Player 1's hand: AH QH JH KS QS
# Player 2's hand: AC KC QC QD 10S
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (12, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: H
# Player 1's hand: AC 10C JC QH KS
# Player 2's hand: KC QC AD 10D KH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (0, None), alphabeta said: (12, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: S
# Player 1's hand: AC QC KD KH KS
# Player 2's hand: 10C AD JD AH JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (11, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 38, pending: 0
# Player 2's points: 38, pending: 0
# The trump suit is: D
# Player 1's hand: KC QC JC 10H QS
# Player 2's hand: AC QD JD QH JH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: D
# Player 1's hand: KC AD 10D QD JS
# Player 2's hand: AC QC KD JH AS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (15, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: S
# Player 1's hand: 10C AD 10D KH JS
# Player 2's hand: KC QH JH AS KS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: S
# Player 1's hand: 10C JC 10D QH QS
# Player 2's hand: KC AD AH KH 10S
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (0, None), alphabeta said: (10, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: 10C JD 10H KH JS
# Player 2's hand: AC QC KD AH QH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (15, None). State: The game is in phase: 2
# Player 1's points: 22, pending: 0
# Player 2's points: 22, pending: 0
# The trump suit is: D
# Player 1's hand: KD JD AH JH 10S
# Player 2's hand: AD 10D 10H KH AS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (6, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 41, pending: 0
# Player 2's points: 41, pending: 0
# The trump suit is: H
# Player 1's hand: JC 10D KD QH AS
# Player 2's hand: 10C QD JD 10H JH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (0, None), alphabeta said: (16, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: D
# Player 1's hand: AC 10C 10S QS JS
# Player 2's hand: KC JC KD JH AS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (12, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: H
# Player 1's hand: 10C KC QD KH QS
# Player 2's hand: AC QC KD JH 10S
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (11, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 35, pending: 0
# Player 2's points: 35, pending: 0
# The trump suit is: C
# Player 1's hand: 10C JC KD QH JS
# Player 2's hand: QC JD 10H 10S KS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (9, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 41, pending: 0
# Player 2's points: 41, pending: 0
# The trump suit is: C
# Player 1's hand: KC JC 10D JD AH
# Player 2's hand: AC QC QH JH 10S
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 22, pending: 0
# Player 2's points: 22, pending: 0
# The trump suit is: H
# Player 1's hand: AC 10C 10H KH QS
# Player 2's hand: QC AD JD AH 10S
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (15, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: H
# Player 1's hand: QC JD JH AS JS
# Player 2's hand: KC AD KD AH QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (10, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: H
# Player 1's hand: KD JH AS 10S KS
# Player 2's hand: AC QD JD AH QS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: D
# Player 1's hand: QD JD AH KH JH
# Player 2's hand: 10C AD KD QS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (2, 3), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: S
# Player 1's hand: 10C KC QC KD JS
# Player 2's hand: JC 10D KH 10S KS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (6, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 29, pending: 0
# Player 2's points: 29, pending: 0
# The trump suit is: D
# Player 1's hand: 10C JD AH KH KS
# Player 2's hand: KC 10D AS QS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (14, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: D
# Player 1's hand: 10D QD AS 10S KS
# Player 2's hand: QC JD KH JH QS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (7, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: S
# Player 1's hand: QC AD QD 10H JS
# Player 2's hand: KD JD AH JH AS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (7, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: C
# Player 1's hand: 10C KD AH JH 10S
# Player 2's hand: AC KC JC QD 10H
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: H
# Player 1's hand: AD KD JD 10H JH
# Player 2's hand: AC AH KH QH JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (0, None), alphabeta said: (5, None). State: The game is in phase: 2
# Player 1's points: 35, pending: 0
# Player 2's points: 35, pending: 0
# The trump suit is: S
# Player 1's hand: QC 10D QH KS QS
# Player 2's hand: AC 10C AD 10H KH
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (7, 8), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: H
# Player 1's hand: JD 10H KH 10S KS
# Player 2's hand: 10C JC KD QD JH
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (15, None), alphabeta said: (6, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: C
# Player 1's hand: 10D JD 10H JH AS
# Player 2's hand: KC AH QH KS QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (5, None), alphabeta said: (0, None). State: The game is in phase: 2
# Player 1's points: 32, pending: 0
# Player 2's points: 32, pending: 0
# The trump suit is: H
# Player 1's hand: KD JD KH JH KS
# Player 2's hand: AC KC AD QD AH
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (15, None), alphabeta said: (10, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: C
# Player 1's hand: AC 10C QC JC 10S
# Player 2's hand: AH 10H AS KS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (18, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 30, pending: 0
# Player 2's points: 30, pending: 0
# The trump suit is: H
# Player 1's hand: 10C KC JC KH QS
# Player 2's hand: AC AD JD 10H QH
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (18, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: C
# Player 1's hand: AC KC QH JH KS
# Player 2's hand: 10C QC 10D JD QS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 33, pending: 0
# Player 2's points: 33, pending: 0
# The trump suit is: H
# Player 1's hand: JC JD JH AS QS
# Player 2's hand: QC AD KD AH KS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (2, None). State: The game is in phase: 2
# Player 1's points: 21, pending: 0
# Player 2's points: 21, pending: 0
# The trump suit is: S
# Player 1's hand: AC 10D AH KS QS
# Player 2's hand: KC AD KD 10H 10S
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (10, None), alphabeta said: (8, None). State: The game is in phase: 2
# Player 1's points: 41, pending: 0
# Player 2's points: 41, pending: 0
# The trump suit is: D
# Player 1's hand: JC 10D QH JH JS
# Player 2's hand: QD AH AS 10S QS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (17, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 34, pending: 0
# Player 2's points: 34, pending: 0
# The trump suit is: C
# Player 1's hand: 10C QC QH JH KS
# Player 2's hand: KC JC 10D QD AS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Difference of opinion! Minimax said: (6, None), alphabeta said: (4, None). State: The game is in phase: 2
# Player 1's points: 39, pending: 0
# Player 2's points: 39, pending: 0
# The trump suit is: S
# Player 1's hand: JC 10D KH JH 10S
# Player 2's hand: KD JD QH QS JS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (9, None), alphabeta said: (6, None). State: The game is in phase: 2
# Player 1's points: 22, pending: 0
# Player 2's points: 22, pending: 0
# The trump suit is: D
# Player 1's hand: AC KC AD KH 10S
# Player 2's hand: 10D JD 10H QH AS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (0, None), alphabeta said: (7, None). State: The game is in phase: 2
# Player 1's points: 37, pending: 0
# Player 2's points: 37, pending: 0
# The trump suit is: C
# Player 1's hand: JC AD JD 10S JS
# Player 2's hand: AC 10C 10D KD QS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (0, None), alphabeta said: (10, None). State: The game is in phase: 2
# Player 1's points: 23, pending: 0
# Player 2's points: 23, pending: 0
# The trump suit is: C
# Player 1's hand: 10C QC 10D KH JS
# Player 2's hand: AC AD JD AH 10H
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (1, None), alphabeta said: (17, None). State: The game is in phase: 2
# Player 1's points: 32, pending: 0
# Player 2's points: 32, pending: 0
# The trump suit is: H
# Player 1's hand: KC KD AH JH QS
# Player 2's hand: 10C AD KH KS JS
# There are 0 cards in the stock
#
# Difference of opinion! Minimax said: (6, None), alphabeta said: (1, None). State: The game is in phase: 2
# Player 1's points: 36, pending: 0
# Player 2's points: 36, pending: 0
# The trump suit is: D
# Player 1's hand: KD QD JD AS 10S
# Player 2's hand: 10C 10D AH QH QS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (5, None), alphabeta said: (3, None). State: The game is in phase: 2
# Player 1's points: 26, pending: 0
# Player 2's points: 26, pending: 0
# The trump suit is: S
# Player 1's hand: QC AD 10D QS JS
# Player 2's hand: 10C QD AH AS KS
# There are 0 cards in the stock
#
# Agreed.
# Difference of opinion! Minimax said: (15, None), alphabeta said: (10, None). State: The game is in phase: 2
# Player 1's points: 36, pending: 0
# Player 2's points: 36, pending: 0
# The trump suit is: C
# Player 1's hand: AH 10H AS 10S KS
# Player 2's hand: AC KC JC QS JS
# There are 0 cards in the stock
#
# Agreed.
# Agreed.
# Done. time Minimax: 1.324978747367859, time Alphabeta: 1.0706539011001588.
# Alphabeta speedup: 1.2375416051876025

# %% [markdown]
# ## Final Task: Collect all the results
#
# Uncomment and run this cell (and all the cells above) to generate the text file that you have to hand in together with the notebook on canvas!
#
# ### Please hand in only the text file which is generated by this method!

# %%
from utils import *
exportToText("assignment5.txt", Report1, Report2, MyCode1, MyCode2)
